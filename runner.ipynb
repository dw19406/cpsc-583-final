# %%
# %run merge.py --dataset cora --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='cora', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset cora | num nodes 2708 | num edge 10556 | num node feats 1433 | num classes 7
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run concat.py --dataset cora --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='cora', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset cora | num nodes 2708 | num edge 10556 | num node feats 1433 | num classes 7
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run main.py --dataset cora --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='cora', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset cora | num nodes 2708 | num edge 10556 | num node feats 1433 | num classes 7
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run main.py --dataset cora --method gat --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='gat', dataset='cora', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset cora | num nodes 2708 | num edge 10556 | num node feats 1433 | num classes 7
# MODEL: GAT(
#   (convs): ModuleList(
#     (0): GATConv(1433, 32, heads=8)
#     (1): GATConv(256, 7, heads=1)
#   )
# )
# Run 01:
# Highest Train: 89.36
# Highest Valid: 84.19
# Highest Test: 83.90
# Chosen epoch: 280
# Final Train: 88.48
# Final Test: 83.16
# Run 02:
# Highest Train: 88.85
# ...

# %%
# %run main.py --dataset cora --method gcn --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='gcn', dataset='cora', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset cora | num nodes 2708 | num edge 10556 | num node feats 1433 | num classes 7
# MODEL: GCN(
#   (convs): ModuleList(
#     (0): GCNConv(1433, 32)
#     (1): GCNConv(32, 7)
#   )
# )
# Run 01:
# Highest Train: 62.11
# Highest Valid: 59.97
# Highest Test: 56.28
# Chosen epoch: 298
# Final Train: 61.82
# Final Test: 56.13
# Run 02:
# Highest Train: 57.68
# Highest Valid: 57.02
# ...

# %%
# %run merge.py --dataset citeseer --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='citeseer', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset citeseer | num nodes 3327 | num edge 9104 | num node feats 3703 | num classes 6
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run concat.py --dataset citeseer --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='citeseer', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset citeseer | num nodes 3327 | num edge 9104 | num node feats 3703 | num classes 6
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run main.py --dataset citeseer --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='citeseer', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset citeseer | num nodes 3327 | num edge 9104 | num node feats 3703 | num classes 6
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run main.py --dataset citeseer --method gat --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='gat', dataset='citeseer', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset citeseer | num nodes 3327 | num edge 9104 | num node feats 3703 | num classes 6
# MODEL: GAT(
#   (convs): ModuleList(
#     (0): GATConv(3703, 32, heads=8)
#     (1): GATConv(256, 6, heads=1)
#   )
# )
# Run 01:
# Highest Train: 77.51
# Highest Valid: 73.16
# Highest Test: 76.83
# Chosen epoch: 139
# Final Train: 75.77
# Final Test: 74.79
# Run 02:
# Highest Train: 77.45
# ...

# %%
# %run main.py --dataset citeseer --method gcn --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='gcn', dataset='citeseer', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset citeseer | num nodes 3327 | num edge 9104 | num node feats 3703 | num classes 6
# MODEL: GCN(
#   (convs): ModuleList(
#     (0): GCNConv(3703, 32)
#     (1): GCNConv(32, 6)
#   )
# )
# Run 01:
# Highest Train: 75.05
# Highest Valid: 72.56
# Highest Test: 74.31
# Chosen epoch: 291
# Final Train: 74.86
# Final Test: 74.07
# Run 02:
# Highest Train: 75.05
# ...

# %%
# %run merge.py --dataset pubmed --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='pubmed', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset pubmed | num nodes 19717 | num edge 88648 | num node feats 500 | num classes 3
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run concat.py --dataset pubmed --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='pubmed', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset pubmed | num nodes 19717 | num edge 88648 | num node feats 500 | num classes 3
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run main.py --dataset pubmed --method nodeformer --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='nodeformer', dataset='pubmed', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset pubmed | num nodes 19717 | num edge 88648 | num node feats 500 | num classes 3
# MODEL: NodeFormer(
#   (convs): ModuleList(
#     (0-1): 2 x NodeFormerConv(
#       (Wk): Linear(in_features=32, out_features=128, bias=True)
#       (Wq): Linear(in_features=32, out_features=128, bias=True)
#       (Wv): Linear(in_features=32, out_features=128, bias=True)
# ...

# %%
# %run main.py --dataset pubmed --method gat --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='gat', dataset='pubmed', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset pubmed | num nodes 19717 | num edge 88648 | num node feats 500 | num classes 3
# MODEL: GAT(
#   (convs): ModuleList(
#     (0): GATConv(500, 32, heads=8)
#     (1): GATConv(256, 3, heads=1)
#   )
# )
# Run 01:
# Highest Train: 84.44
# Highest Valid: 84.05
# Highest Test: 84.99
# Chosen epoch: 280
# Final Train: 84.36
# Final Test: 84.91
# Run 02:
# Highest Train: 84.64
# ...

# %%
# %run main.py --dataset pubmed --method gcn --lr 0.001 --weight_decay 0.001 --num_layers 2 --hidden_channels 32 --num_heads 4 --rb_order 2 --rb_trans sigmoid --lamda 1.0 --M 30 --K 10 --runs 3 --epochs 300 --device 0
# Out:
# Namespace(method='gcn', dataset='pubmed', data_dir='', device=0, epochs=300, eval_step=1, runs=3, train_prop=0.5, valid_prop=0.25, protocol='semi', rand_split=False, rand_split_class=False, label_num_per_class=20, metric='acc', knn_num=5, save_model=False, model_dir='../model/', hidden_channels=32, dropout=0.0, lr=0.001, weight_decay=0.001, num_layers=2, num_heads=4, M=30, use_residual=False, use_bn=False, use_act=False, use_jk=False, K=10, tau=0.25, lamda=1.0, rb_order=2, rb_trans='sigmoid', batch_size=10000, hops=1, cached=False, gat_heads=8, out_heads=1, projection_matrix_type=True, directed=False)
# dataset pubmed | num nodes 19717 | num edge 88648 | num node feats 500 | num classes 3
# MODEL: GCN(
#   (convs): ModuleList(
#     (0): GCNConv(500, 32)
#     (1): GCNConv(32, 3)
#   )
# )
# Run 01:
# Highest Train: 82.24
# Highest Valid: 81.96
# Highest Test: 82.41
# Chosen epoch: 299
# Final Train: 82.23
# Final Test: 82.39
# Run 02:
# Highest Train: 81.72
# Highest Valid: 81.54
# ...
